# %% [markdown]
# <a href="https://colab.research.google.com/github/ag0466154-cpu/Unidad-4_Estadistica2025B-/blob/main/Proyecto_Unidad_3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Introducción**
#
# Las falsificaciones han sido un delito que tiene mucho impacto que afecta significativamente en la economía, seguridad pública y la confianza en las instituciones gubernamentales en México.
# Este delito no solo hace que haya pérdidas económicas, sino que también destruye con ideales legales y favorece la operación de redes criminales organizadas con esto el análisis cuantitativo del comportamiento que tiene con el tiempo puede ser una herramienta importante para crear políticas públicas que estén basadas en evidencias.
#
# Este proyecto está enfocado en el estudio de la serie temporal de los casos de falsificación registrado en el Estado de México durante enero de 2012 al octubre del 2023, con el objetico de identificar patrones temporales que estén asociados con este delito, identificar componentes estacionales y detectar ciclos recurrentes que puedan ser base para estrategias de prevención más efectivas.
#
# Este proyecto se da gracias a la necesidad de estudiar el enfoque de seguridad pública preventivo y proactivo. Mediante análisis estadísticos de datos históricos se busca crear una herramienta analítica que permita optimizar recursos, anticipar periodos donde se dé más el delito y evaluar el impacto de las intervenciones que se implementen.
#
# Los hallazgos de este estudio buscan contribuir a que se entienda de mejor forma la dinámica temporal de las falsificaciones en México, ofreciendo conclusiones basadas en datos para poder tomar decisiones más informadas en la seguridad pública y se busca brindar un método que puede ser utilizado para que se puedan analizar otros delitos para que el diseño de políticas sea sustentado.
#
# A continuación, se presenta del desarrollo del proyecto organizado por secciones comenzando desde un marco teórico, y metodología que son bases para el entendimiento de los resultados de este proyecto, así como sus conclusiones y su utilidad práctica para la prevención del delito de falsificación.

# %% [markdown]
# # **Marco Teórico**
#
# **Series de tiempo**
#
# Una serie de tiempo es un conjunto de observaciones recolectadas secuencialmente en el tiempo. Su análisis permite identificar patrones compuestos por:
#
# * Tendencia:La tendencia a largo plazo de una serie de aumentar o disminuir (tendencia creciente o tendencia decreciente).
# * Estacionalidad:La fluctuación periódica en las series de tiempo dentro de un período determinado. Estas fluctuaciones forman un patrón que tiende a repetirse de un período estacional al siguiente.
# * Ruido o componente irregular:El movimiento que queda después de explicar los movimientos de tendencia, estacionales y cíclicos; ruido aleatorio o error en una serie de tiempo.
#
# **Método de mínimos cuadrados**
#
# Consiste en ajustar un modelo funcional (lineal o no lineal) que minimiza la suma de los cuadrados de las diferencias entre los valores observados y los estimados. En series de tiempo se usa para modelar tendencias.
#
# **Promedios móviles**
#
# Los promedios móviles suavizan la serie eliminando fluctuaciones irregulares. Existen:
# * Promedio móvil simple (SMA): media de los últimos k datos.
# * Promedio móvil exponencial (SES): asigna más peso a los datos recientes.
#
# Ambos permiten visualizar la tendencia subyacente.
#
# **Suavización exponencial**
#
# El suavizado exponencial es una técnica de pronóstico de series temporales que utiliza promedios ponderados para predecir valores futuros basándose en observaciones pasadas. Asigna ponderaciones exponencialmente decrecientes a los datos más antiguos, otorgando mayor importancia a las observaciones recientes. Este enfoque captura tendencias y patrones en los datos, lo que permite a las empresas realizar predicciones precisas.
#
# El suavizado exponencial funciona asignando ponderaciones a los puntos de datos históricos, donde las ponderaciones disminuyen exponencialmente a medida que las observaciones se hacen más antiguas. La técnica considera tres componentes principales:
#
#
#
# * Nivel: El valor promedio de la serie temporal.
#
# * Tendencia: La dirección y magnitud de la serie temporal a lo largo del tiempo.
#
# * Estacionalidad: Patrones periódicos o fluctuaciones que ocurren en las series de tiempo.
#
# Al aplicar pesos apropiados a estos componentes, el suavizado exponencial genera pronósticos que pueden capturar diferentes patrones y variaciones en los datos.
#
# La suavización exponencial es crucial para las empresas de varias maneras:
#
#
# * Pronóstico preciso: la suavización exponencial proporciona a las empresas predicciones precisas de valores futuros, lo que les permite tomar decisiones informadas y optimizar sus operaciones.
#
# * Detección de tendencias: la técnica ayuda a identificar y analizar tendencias en datos de series temporales, lo que permite a las empresas comprender la dinámica del mercado y anticipar los cambios.
#
# * Análisis de estacionalidad: la suavización exponencial puede descubrir patrones y fluctuaciones estacionales, lo que permite a las empresas ajustar sus estrategias y operaciones en consecuencia.
#
# * Planificación mejorada: con pronósticos precisos, las empresas pueden planificar sus recursos, inventario y cronogramas de producción de manera más efectiva, minimizando costos y optimizando la eficiencia.
#
# **Tendencias no lineales**
#
# Cuando la tendencia no es lineal, pueden emplearse modelos polinómicos de orden superior, curva logística, exponencial o spline. En el proyecto se aplicó un modelo polinómico de grado 10.
#
# **Variación estacional**
#
# La estacionalidad corresponde a fluctuaciones regulares de la serie. Se evalúa con:
# Descomposición clásica (aditiva o multiplicativa)
# Transformada de Fourier
# Pruebas estadísticas (prueba t entre tendencia y tendencia+estacionalidad)
#
#
#
# **Pruebas de estacionariedad**
#
# La estacionariedad en la prueba de estacionariedad es una propiedad de las series de tiempo que establece que el valor de la variable no cambia con el tiempo, es decir, la variación en el tiempo no sirve como un factor que produzca cambios en el valor de una variable.
#
# Una serie estacionaria tiene media y varianza constantes. Se utiliza la prueba
# ADF (Augmented Dickey-Fuller):
#
# * H0: La serie tiene raíz unitaria (no estacionaria)
# * H1: La serie es estacionaria

# %% [markdown]
# # **Metodología**
#
# Este proyecto se llevará de manera secuencial iniciando por el vaciado de datos el cual implica descargar la base de datos mexico_cime.csv y cargarla en Colab, después se filtraran los datos para seleccionar solo una entidad de interés y de ahí se construirá una variable para fecha que sea válida y nos permita trabajar de manera más fácil a partir de un mapeo de los nombres de los meses a número, el siguiente paso es seleccionar un tipo de crimen para el análisis y al final se agrupan los datos por fecha, con los conteos mensuales y así obtener la serie de tiempo la cual se subira a GitHub para que nos arroje el link de los datos crudos, volver a vaciar los datos en Colab y sea posible trabajar la serie de tiempo que sera la base para el estudió.
#
# Para poder obervar la tendencia general y reducir el ruido de variaciones a corto plazo se utulizaran dos tècnicas de suavizado, una media movil simple de 12 meses y una suavizaciòn exponencial con la misma ventana temporal  ambas se calcuaran sobre la serie original para poder comparar de forma directa para capturar patrones.
#
# Se aplicara la preba de Dickey - Fuller Aumentada para poder determinar si la serie presenta raices unitarias, esta prueba evalua la hiposteis nula de no estacionariedad contra la alternativa de estacionariedad, se utilizara un nivel de significac¡ncia de 0.05 y posteriormente se aplicara un modelo de regresipon polinomial de grado 10.
#
# Sobre los residuos del modelo polinomial se palicara el analisis de series de fourier para poder identificar condas periodicas que oscilan suavemente, y que nos permita identificar cilcos independientemente de la tendencia. Despuès se realizara la descomposiciòn de la serie, se separara la serie en tres componentes que son tendencia, estacionalidad y residuo, se especificara un periodo de 12 meses para que vaya acrode a la naturaleza de los daros.
#
# De igula manera se realizara un conjunto de visualizaciones comparativas que compararn la serie original contra la serie reconstruida, la tendencia aislada contra la combinaciòn de tendencia y estacionalidad y la serie sin comoponente estacional contra la serie completa, esro para que nos permita hacer observaciones preliminares de la amgnitud y patron de la estacionalidad.
#
# Para poder saber si la etacionalidad tiene un efecto significativo se realizara la prueba t  pareada para poder comparar la serie de tendencia contr la serie combinada de tendencia màs estacionalidad, nos permitira observar las diferencias sistemàticas entre ambas series.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/ag0466154-cpu/Estadistica2025B/refs/heads/main/proyecto_3.csv")
df["Date"] = pd.to_datetime(df["Date"])
df.set_index("Date", inplace=True)
df
# Out:
#             count
# Date
# 2015-01-01    135
# 2015-02-01    116
# 2015-03-01    125
# 2015-04-01    117
# 2015-05-01    118
# ...           ...
# 2023-06-01    208
# 2023-07-01    216
# 2023-08-01    230
# 2023-09-01    193
# 2023-10-01    219
#
# [106 rows x 1 columns]

# %% [markdown]
# ## **a) Representación del grafico (Media exponencial y Media movil)**

# %%
# Promedio Móvil Simple
import matplotlib.pyplot as plt

ventana_sma = 12
df['SMA'] = df['count'].ewm(span=ventana_sma, adjust=False).mean()

# Promedio Móvil Exponencial
ventana_ses = 8
df['SES'] = df['count'].ewm(span=ventana_ses, adjust=False).mean()

# Graficar
plt.figure(figsize=(12, 6))
plt.plot(df['count'], label='Cantidad de falsificaciones', color='blue')
plt.plot(df['SMA'], label=f'Promedio Móvil ({ventana_sma} días)', color='orange')
plt.plot(df['SES'], label=f'Suavización Exponencial ({ventana_ses} días)', color='green')
plt.title('Promedio Móvil de Cantidad de falsificaciones')
plt.xlabel('Fecha')
plt.ylabel('Cantidad de falsificaciones')
plt.grid()
plt.legend()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# ## **b) Dickey - Fuller Aumentada**

# %%
#Prueba de estacionariedad: Prueba de Dickey-Fuller aumentada (ADF)

#Hipótesis nula (H₀): La serie tiene una raíz unitaria (no es estacionaria).
#Hipótesis alternativa (H₁): La serie es estacionaria.

from statsmodels.tsa.stattools import adfuller

nivel_de_significancia = 0.05

# Realizar la prueba de Dickey-Fuller en los la tendencia
adf_test = adfuller(df['count'].dropna()) # Realiza la prueba ADF


# Interpretación de la prueba ADF
print('Estadístico ADF:', adf_test[0])
print('p-value:', adf_test[1])

if adf_test[1] <= nivel_de_significancia:
    print("La tendencia es estacionaria (rechazamos la hipótesis nula).")
else:
    print("La tendencia no es estacionaria (aceptamos la hipótesis nula).")
# Out:
# Estadístico ADF: -2.495014261746475
# p-value: 0.11669212636374365
# La tendencia no es estacionaria (aceptamos la hipótesis nula).

# %% [markdown]
# ## **c) Regresión polinomial**

# %%
from numpy.polynomial.polynomial import Polynomial
import matplotlib.pyplot as plt
import pandas as pd

# Paso 1: Convertir fechas a números
# Creamos una nueva columna llamada 'Date' la cual contiene las fechas en
# segundos desde el 1 de de enero de 1970 (tiempo UNIX)
df['Date'] = df.index.map(pd.Timestamp.timestamp)

# Paso 2: Definir las variables independientes (X) y la variable dependiente (y)
X = df['Date']
y = df['count']

# Paso 3: Ajustar un modelo polinómico
grado = 10
modelo = Polynomial.fit(X, y, deg = grado)
df['Poly_Trend'] = modelo(X)
df['Poly_Resid'] = y - df['Poly_Trend']

# Graficar polinomial
# abre una nueva ventana gráfica
plt.figure(
    figsize=(12, 6) # tamaño (horizontal, vertical)
    )

# qué se va a graficar:
plt.plot(
    y,
    label='Cantidad de Falsificaciones', # etiqueta que aparecerá en la leyenda
    color='green'
    )

plt.plot(df['Poly_Trend'], label=f'Tendencia Polinómica (Grado {grado})', color='purple')
plt.title('Tendencia No Lineal de Conteo de falsificaciones') # Título
plt.xlabel('Fecha')                                           # nombre del eje x
plt.ylabel('Cantidad de Falsificaciones')                            # nombre del eje y
plt.legend()                                                  # agrega la leyenda
plt.grid()                                                    # agrega una cuadrícula
plt.gca().spines['top'].set_visible(False)                    # elimina los bordes superiores
plt.gca().spines['right'].set_visible(False)                  # elimina los bordes derechos
plt.show()                                                    # muestra el gráfico (innecesario en colab)




# Graficar los residuales del polinomio
plt.figure(figsize=(12, 6)) # abre una nueva ventana gráfica
plt.plot(df['Poly_Resid'], label='Residuales', color='blue')
plt.axhline(0, color='red', label='Regresion',linestyle='--', linewidth=1)  # Línea horizontal en el valor cero
plt.title('Residuales de la regresión polinomial de Conteo de Falsificaciones')
plt.xlabel('Fecha')
plt.ylabel('Desviación de la regresión polinomial de Falsificaciones')
plt.legend()
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# ## **d) Series de Fourier**

# %%
# Aquí no le muevan a nada
# Básicamente, lo que se hace este bloque es crear la función
# Transformada_de_Fourier, puesto a que no existe para lo que la quiero usar.

def Transformada_de_Fourier(serie, terminos, un_grafico, termino):
  '''La función acepta los argumentos "serie", la cual debe de ser un array
  en numpy y en pandas de la forma df["my_variable"].values. Por otra parte,
  el parámetro "terminos" es un número natural que indica la cantidad de
  términos que desarrolla la serie. Entre mayor sea el número de términos,
  la serie será más precisa, pero más difícil de interpretar.

  La función tiene como salida una lista con los componentes sinosoidales de serie.
  El último elemento de la lista, es la suma de todos los componentes'''

  import numpy as np
  import matplotlib.pyplot as plt
  import pandas as pd
  from scipy.fftpack import fft, ifft

  # Supongamos que tienes una serie en df['AAPL_Close']
  # Reemplaza esta línea con tu DataFrame y serie específicos
  n = len(serie)

  # Calcular la transformada de Fourier
  transformada_fourier = fft(serie)

  # Obtener las frecuencias
  frecuencias = np.fft.fftfreq(n)

  # Crear un DataFrame para almacenar la frecuencia y su magnitud
  componentes = pd.DataFrame({
      'frecuencia': frecuencias,
      'magnitud': np.abs(transformada_fourier),
      'longitud_de_onda': 1 / frecuencias
  })

  # Ordenar el dataframe de mayor a menor en términos de magnitud

  componentes = componentes.sort_values(by='magnitud', ascending=False)

  # Seleccionar las frecuencias con mayor magnitud (excluyendo la frecuencia cero)
  top_frecuencias = componentes.loc[componentes['frecuencia'] > 0].nlargest(terminos, 'magnitud')
  top_frecuencias.reset_index(drop=True, inplace=True)
  print("Frecuencias principales:\n", top_frecuencias)

  # Crear el índice de tiempo para la serie
  t = np.arange(n)

  # Graficar cada componente de frecuencia junto con la serie original
  plt.figure(figsize=(12, 4))

  componente_temporal_sumado = np.zeros_like(serie)
  componentes_temporales = []

  n=0
  for i, row in top_frecuencias.iterrows():
      n+=1
      # Copiar la transformada de Fourier y mantener solo la frecuencia actual
      fourier_component = np.zeros_like(transformada_fourier)
      idx = np.where(frecuencias == row['frecuencia'])[0][0]  # índice de la frecuencia en la FFT
      fourier_component[idx] = transformada_fourier[idx]  # mantener solo la frecuencia positiva
      fourier_component[-idx] = transformada_fourier[-idx]  # mantener la frecuencia negativa correspondiente
      if n == (terminos+1):
        break

      # Reconstruir la señal en el tiempo
      componente_temporal = ifft(fourier_component).real
      componentes_temporales.append(componente_temporal)
      componente_temporal_sumado += componente_temporal
      if i == termino:
          df["seasonal_poly"] = componente_temporal

      # Graficar la componente
      plt.plot(
          componente_temporal,
          label=f'Longitud de onda {1 / row["frecuencia"]:.0f}',
          alpha=1,
          linewidth = 0.5,
          )
      plt.title('Componentes de Fourier de la Serie')
      plt.xlabel('Tiempo')
      plt.ylabel('Valor')
      plt.legend()
      plt.grid()

  componentes_temporales.append(componente_temporal_sumado)
  plt.plot(serie, label='Serie Original', color='black', alpha=0.5)
  if not un_grafico:
    plt.figure(figsize=(12, 4))
    plt.plot(serie, label='Serie Original', color='black', alpha=0.5)
  plt.plot(componente_temporal_sumado, label='Componente temporal sumada', color='red')
  plt.legend()
  plt.title('Suma de los Componentes de Fourier de la Serie')
  plt.xlabel('Tiempo')
  plt.ylabel('Valor')
  plt.grid()
  plt.show()

  return componentes_temporales

# %%
serie = df['Poly_Resid'].values
terminos = 5
un_grafico = True # Changed to True

cts = Transformada_de_Fourier(serie, terminos, un_grafico, 2)

# cts: componente temporal sumado
# Out:
# /tmp/ipython-input-3634185557.py:34: RuntimeWarning: divide by zero encountered in divide
#   'longitud_de_onda': 1 / frecuencias
# Frecuencias principales:
#     frecuencia     magnitud  longitud_de_onda
# 0    0.056604  1165.255179         17.666667
# 1    0.047170  1037.126666         21.200000
# 2    0.113208   609.472091          8.833333
# 3    0.103774   575.827599          9.636364
# 4    0.160377   510.016838          6.235294

# %%
df
# Out:
#             count         SMA         SES          Date  Poly_Trend  \
# Date
# 2015-01-01    135  135.000000  135.000000  1.420070e+09  139.582580
# 2015-02-01    116  132.076923  130.777778  1.422749e+09  117.417122
# 2015-03-01    125  130.988166  129.493827  1.425168e+09  109.667254
# 2015-04-01    117  128.836140  126.717421  1.427846e+09  109.998591
# 2015-05-01    118  127.169042  124.780216  1.430438e+09  115.669686
# ...           ...         ...         ...           ...         ...
# 2023-06-01    208  206.927466  204.511236  1.685578e+09  194.303436
# 2023-07-01    216  208.323240  207.064294  1.688170e+09  194.600197
# 2023-08-01    230  211.658126  212.161118  1.690848e+09  199.390194
# 2023-09-01    193  208.787645  207.903092  1.693526e+09  210.466339
# 2023-10-01    219  210.358777  210.369071  1.696118e+09  229.176483
#
#             Poly_Resid  seasonal_poly
# Date
# 2015-01-01   -4.582580       7.282927
# 2015-02-01   -1.417122      -0.292736
# ...

# %%
plt.plot(df["count"])
plt.plot(df["Poly_Trend"])
plt.plot(df["Poly_Trend"] + df['seasonal_poly'])

# %% [markdown]
# ## **e) Descomposición de la serie**

# %%
# Descomponer la serie temporal
import statsmodels.api as sm

descomposicion = sm.tsa.seasonal_decompose(
    df['count'],
    model='additive',
    period=12,
    extrapolate_trend=0,
    two_sided=False,
    )
fig = descomposicion.plot()
plt.show()

# %%
#Prueba de estacionariedad: Prueba de Dickey-Fuller aumentada (ADF)

#Hipótesis nula (H₀): La serie tiene una raíz unitaria (no es estacionaria).
#Hipótesis alternativa (H₁): La serie es estacionaria.

from statsmodels.tsa.stattools import adfuller

nivel_de_significancia = 0.05

# Realizar la prueba de Dickey-Fuller en los la tendencia
adf_test = adfuller(descomposicion.resid.dropna()) # Realiza la prueba ADF


# Interpretación de la prueba ADF
print('Estadístico ADF:', adf_test[0])
print('p-value:', adf_test[1])

if adf_test[1] <= nivel_de_significancia:
    print("La tendencia es estacionaria (rechazamos la hipótesis nula).")
else:
    print("La tendencia no es estacionaria (aceptamos la hipótesis nula).")
# Out:
# Estadístico ADF: -2.9966092332579524
# p-value: 0.03521227086438419
# La tendencia es estacionaria (rechazamos la hipótesis nula).

# %% [markdown]
# ## **f) Graficos (efectos significativos de estacionalidad)**

# %%
# Graficar descomposición
plt.figure(figsize=(12, 6)) # abre una nueva ventana gráfica
plt.plot(df['count'], label='Cantidad de falsificaciones', color='blue')
plt.plot(descomposicion.trend + descomposicion.seasonal + descomposicion.resid, label=f'Suma de la descomposición', color='purple')
plt.title('Serie de tiempo real vs serie de tiempo descompuesta')
plt.xlabel('Fecha')
plt.ylabel('Cantidad de falsificaciones')
plt.legend()
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %%
# Graficar descomposición
plt.figure(figsize=(12, 6)) # abre una nueva ventana gráfica
plt.plot(df['count'], label='Cantidad de falsificaciones', color='blue')
plt.plot(descomposicion.trend + descomposicion.seasonal, label=f'Suma de la descomposición', color='purple')
plt.title('Serie de tiempo real vs serie de tiempo descompuesta sin residuales')
plt.xlabel('Fecha')
plt.ylabel('Cantidad de falsificaciones')
plt.legend()
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %%
# Graficar descomposición
plt.figure(figsize=(12, 6)) # abre una nueva ventana gráfica
plt.plot(descomposicion.trend, label='Tendencia', color='blue')
plt.plot(descomposicion.trend + descomposicion.seasonal, label=f'Tendencia y estacionalidad', color='purple')
plt.title('Tendencia vs serie de tiempo descompuesta sin residuales')
plt.xlabel('Fecha')
plt.ylabel('Cantidad de falsificaciones')
plt.legend()
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %%
# Graficar descomposición
plt.figure(figsize=(12, 6)) # abre una nueva ventana gráfica
plt.plot(df['count'], label='Precio de cierre', color='blue')
plt.plot(descomposicion.trend + descomposicion.resid, label=f'Suma de la descomposición', color='purple')
plt.title('Serie de tiempo real vs serie de tiempo descompuesta sin el componente estacional')
plt.xlabel('Fecha')
plt.ylabel('Cantidad de falsificaciones')
plt.legend()
plt.grid()
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.show()

# %% [markdown]
# ## **g) Prueba t pareada para verificar si la estacionalidad tiene un efecto significativo**

# %%
from scipy.stats import ttest_rel

# Prueba t pareada para el efecto significativo de la estacionalidad

#Hipótesis nula (H₀): Ambas series son iguales.
#Hipótesis alternativa (H₁): Ambas series son diferentes


nivel_de_significancia = 0.05
tendencia = descomposicion.trend
tendencia_estacionalidad = descomposicion.seasonal + descomposicion.trend

# Eliminar valores NaN de ambas series
tendencia.dropna(inplace=True)
tendencia_estacionalidad.dropna(inplace=True)

# Realizar la prueba t pareada
t_stat, p_valor = ttest_rel(tendencia, tendencia_estacionalidad)

print("Estadístico t:", t_stat)
print("Valor p:", p_valor)
print("\n")

# Interpretación de los resultados
if p_valor < nivel_de_significancia:
    print("El valor p es menor que 0.05, por lo tanto, rechazamos la hipótesis nula.")
    print("Conclusión: La estacionalidad tiene un efecto significativo en la serie de tiempo.")
else:
    print("El valor p es mayor o igual que 0.05, por lo tanto, no podemos rechazar la hipótesis nula.")
    print("Conclusión: La estacionalidad no tiene un efecto significativo en la serie de tiempo.")
# Out:
# Estadístico t: 0.0035150576513084185
# Valor p: 0.9972029245971439
#
#
# El valor p es mayor o igual que 0.05, por lo tanto, no podemos rechazar la hipótesis nula.
# Conclusión: La estacionalidad no tiene un efecto significativo en la serie de tiempo.

# %% [markdown]
# # **Conclusiones**
#
#
#
# *   En los gráficos de media móvil simple y suavización exponencial se puede ver que las falsificaciones en México tienen una tendencia ascendente desde el 2015, tienen fluctuaciones importantes sin patrones estacionales claros a simple vista, las dos técnicas de suavizado presentan un crecimiento continuo a partir del 2018 - 2019.
#
# *   La prueba ADF que se aplicó en la serie original dio un valor - p de 0.1167 entonces la serie de falsificaciones no es estacionaria y tiene una raíz unitaria y el resultado mismo nos pidió realizar una descomposición y modelo de tendencia por que la serie tiene dependencia temporal significativa.
#
# * En la regresión polinomial de grado 10 se pudo presentar la tendencia no lineal ascendente de las falsificaciones y el crecimiento no es constante ni uniforme si no que a veces se presenta aceleraciones y desaceleraciones en periodos y tiene un incremento en últimos años del periodo 2021 - 2023.
#
# * Las series de Fourier identifico ciclos de mediano plazo en los residuos de la regresión polinomial pero no nos dio estacionalidad anual que fuera significativa y las frecuencias principales no dicen que las falsificaciones responden a dinámicas operativas o de mercado que operan en ciclos relativas a más de un año más que mensuales.
#
#
# * La descomposición de la serie separo la serie en tres componentes, una tendencia ascendente dominante, una estacionalidad mínima y residuos estacionarios y se puede decir que la tendencia es el componente más importante para poder explicar el comportamiento de las falsificaciones y la estacionalidad contribuye poco en la variación total.
#
# * En la comparación grafica entre la serie original y la serie descompuesta se puede observar la ausencia de patrones estacionales y se puede ver que la serie reconstruida sin el componente estacional se aproxima bien a la serie original, mientras que la inclusión de la estacionalidad no mejora significativamente el ajuste.
#
# * La prueba t pareada entre la tendencia y la tendencia más la estacionalidad nos da un valor - p de 0.9972 lo que confirma que la estacionalidad no tiene un efecto significativo en la serie de falsificaciones y así que no tenemos que hacer ajustes estacionales para la prevención y asignación de recursos.
#
#
# **Utilidad en seguridad publica:**
#
#
# Ahora sabemos que no hay meses específicos del año donde se den más falsificaciones entonces la policia y las autoridades deben trabajar con la misma intesidad todos los meses, sin tener que reforzar la cigilancia en ciertas temporadas y dejar de hacerlo en otras.
#
# También se descuvrio que las falsificaciones aumentan año con año desde el 2018 entonces se neceistan planeas para varios años para poder controlar el problema no nadmas operativos que duren ciertos meses, las autoridades pueden usar este analisis para poder tener presupuestos más grande y mejores planeados ya que se muestra con datos que el problema crece de forma continua.
#
# Hay ciclos de varios meses entre 6 y 21 meses donde las falsificaciónes suben y bajan, esto puede ayudar a la policia a anticipar cuando puede haber repuntes y preparar operativos para prevención con tiempo en lugar de reaccionar cuando hay se dieron muchos casos.
#
# Estos hallazgos permiten ahorrar recursos y usarlos de mejor manera, como el dinero y el personal se puede distribuir de forma más inteligente y estrategica para atacar las causas de el crecimiento de este delito y poder estar alerta cuando se cercan cilcos de mayor riesgo.

# %% [markdown]
# # **Referencias**
#
# Abril, J. C. (2011, 1 diciembre). Análisis de la evolución de las técnicas de series de tiempo: Un enfoque unificado. https://ri.conicet.gov.ar/handle/11336/71449
#
# Darío, B. P. L., & Sandra, M. C. (s. f.). Una metodología de series de tiempo para el área de la salud; caso práctico. http://www.scielo.org.co/scielo.php?script=sci_arttext&pid=S0120-386X2007000200014
#
# Métodos para analizar las series de tiempo - Minitab. (s. f.). (C) Minitab, LLC. All Rights Reserved. 2025. https://support.minitab.com/es-mx/minitab/help-and-how-to/statistical-modeling/time-series/supporting-topics/basics/methods-for-analyzing-time-series/
#
# What is Exponential Smoothing? (s. f.). https://h2o.ai/wiki/exponential-smoothing
